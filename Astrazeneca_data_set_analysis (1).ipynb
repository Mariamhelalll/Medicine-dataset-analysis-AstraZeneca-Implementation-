# %% [markdown]
# #Project question & success criteria:
#
# Goal: Build a model to predict or cluster drug side-effects based on drug characteristics and user feedback.
#
# Why this matters (AstraZeneca pharmacovigilance context): post-marketing surveillance needs fast signal detection for adverse events (AEs).
#
#  We want:
#
# Supervised prediction: given a drug’s characteristics + user text, estimate probability that each AE label occurs (multi-label).
#
# Unsupervised clustering: group drugs by similar AE profiles to surface unexpected patterns (signals).
#
# Success metrics: label-wise ROC-AUC and PR-AUC (class-imbalance robust), plus qualitative inspection of clusters/topics for clinical plausibility.

# %% [markdown]
# #Setup & imports (What/Why/How):
#
# What: bring in pandas/numpy for data wrangling; scikit-learn for preprocessing, TF-IDF, pipelines, One-Vs-Rest logistic regression, and evaluation; matplotlib for plots.
#
# Why: ensures we can create a reproducible end-to-end pipeline: raw data → features → model → metrics.
#
# How it builds toward the conclusion: this imports the exact tools we’ll use to deliver both prediction (supervised) and clustering (unsupervised) answers to the project question.

# %%
# === Setup & Imports ===
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_auc_score, average_precision_score, classification_report
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.cluster import KMeans

RANDOM_STATE = 42
plt.rcParams['figure.figsize'] = (9, 5)

# %% [markdown]
# #Load & harmonize raw data:
#
# What: read the datasets (drugs, user reviews/ratings, side-effect labels); standardize column names, strip whitespace, normalize text, and align keys (e.g., medicine_name). Handle missing values.
#
# Why: pharmacovigilance data is messy (duplicates, spelling, missing text). Harmonization avoids data leakage and inconsistent joins.
#
# How it builds: creates one clean analytical table that later splits into features (drug composition/uses/review text) and targets (multi-label side-effects).

# %%
# === Load & Harmonize ===
path = "/content/sample_data/Medicine_Details.csv"
df = pd.read_csv(path)

# Trim header whitespace just in case
df.columns = [c.strip() for c in df.columns]

# Map to consistent names
col_map = {
    "Medicine Name": "medicine_name",
    "Composition": "composition",
    "Uses": "uses",
    "Side_effects": "side_effects",
    "Image URL": "image_url",
    "Manufacturer": "manufacturer",
    "Excellent Review %": "excellent_review",
    "Average Review %": "average_review",
    "Poor Review %": "poor_review",
}
for old, new in col_map.items():
    if old in df.columns:
        df.rename(columns={old: new}, inplace=True)

# Keep the columns we actually use
cols_wanted = [
    "medicine_name","composition","uses","side_effects","image_url",
    "manufacturer","excellent_review","average_review","poor_review"
]
keep = [c for c in cols_wanted if c in df.columns]
df = df[keep].copy()

# Make review columns numeric (strip % if strings)
for c in ["excellent_review","average_review","poor_review"]:
    if c in df.columns and df[c].dtype == object:
        df[c] = pd.to_numeric(df[c].astype(str).str.replace("%", "", regex=False), errors="coerce")

df.head(25)
# Out:
#                       medicine_name  \
# 0           Avastin 400mg Injection
# 1          Augmentin 625 Duo Tablet
# 2               Azithral 500 Tablet
# 3                  Ascoril LS Syrup
# 4                 Aciloc 150 Tablet
# 5              Allegra 120mg Tablet
# 6                    Avil 25 Tablet
# 7                   Aricep 5 Tablet
# 8              Amoxyclav 625 Tablet
# 9                Atarax 25mg Tablet
# 10                  Azee 500 Tablet
# 11                    Anovate Cream
# 12                 Allegra-M Tablet
# 13  Ascoril D Plus Syrup Sugar Free
# 14                       Alex Syrup
# 15                  Armotraz Tablet
# 16    Augmentin Duo Oral Suspension
# 17         Albendazole 400mg Tablet
# 18                   Arkamin Tablet
# 19             Allegra 180mg Tablet
# 20              Altraday Capsule SR
# 21               Atarax 10mg Tablet
# 22              Aldigesic-SP Tablet
# 23                 Aldactone Tablet
# 24                 Aricep 10 Tablet
#
#                                           composition  \
# 0                                 Bevacizumab (400mg)
# 1     Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 2                                Azithromycin (500mg)
# 3   Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4                                  Ranitidine (150mg)
# 5                                Fexofenadine (120mg)
# 6                                  Pheniramine (25mg)
# 7                                     Donepezil (5mg)
# 8     Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 9                                  Hydroxyzine (25mg)
# 10                               Azithromycin (500mg)
# 11  Phenylephrine (0.10% w/w) + Beclometasone (0.0...
# 12          Montelukast (10mg) + Fexofenadine (120mg)
# 13  Phenylephrine (5mg) + Chlorpheniramine Maleate...
# 14  Phenylephrine (5mg/5ml) + Chlorpheniramine Mal...
# 15                                  Anastrozole (1mg)
# 16   Amoxycillin  (200mg) +  Clavulanic Acid (28.5mg)
# 17                                Albendazole (400mg)
# 18                                 Clonidine (100mcg)
# 19                               Fexofenadine (180mg)
# 20           Aceclofenac (200mg) + Rabeprazole (20mg)
# 21                                 Hydroxyzine (10mg)
# 22  Aceclofenac (100mg) + Paracetamol (325mg) + Se...
# 23                              Spironolactone (25mg)
# 24                                   Donepezil (10mg)
#
#                                                  uses  \
# 0    Cancer of colon and rectum Non-small cell lun...
# 1                   Treatment of Bacterial infections
# 2                   Treatment of Bacterial infections
# 3                       Treatment of Cough with mucus
# 4   Treatment of Gastroesophageal reflux disease (...
# 5   Treatment of Sneezing and runny nose due to al...
# 6   Treatment of Allergic conditionsTreatment of R...
# 7                                 Alzheimer's disease
# 8                   Treatment of Bacterial infections
# 9   Treatment of AnxietyTreatment of Skin conditio...
# 10                  Treatment of Bacterial infections
# 11                                 Treatment of Piles
# 12  Treatment of Sneezing and runny nose due to al...
# 13                             Treatment of Dry cough
# 14                             Treatment of Dry cough
# 15                                      Breast cancer
# 16  Treatment of Resistance Tuberculosis (TB)Treat...
# 17                  Treatment of Parasitic infections
# 18    Treatment of Hypertension (high blood pressure)
# 19  Treatment of Sneezing and runny nose due to al...
# 20                                        Pain relief
# 21  Treatment of AnxietyTreatment of Skin conditio...
# 22                                        Pain relief
# 23   Hypertension (high blood pressure) Edema Low ...
# 24                                Alzheimer's disease
#
#                                          side_effects  \
# 0   Rectal bleeding Taste change Headache Noseblee...
# 1   Vomiting Nausea Diarrhea Mucocutaneous candidi...
# 2                      Nausea Abdominal pain Diarrhea
# 3   Nausea Vomiting Diarrhea Upset stomach Stomach...
# 4      Headache Diarrhea Gastrointestinal disturbance
# 5                Headache Drowsiness Dizziness Nausea
# 6                                            Sedation
# 7   Common cold Urinary incontinence Rash Nausea D...
# 8   Vomiting Nausea Diarrhea Mucocutaneous candidi...
# 9   Sedation Nausea Vomiting Upset stomach Constip...
# 10                     Nausea Abdominal pain Diarrhea
# 11  Application site reactions burning irritation ...
# 12  Nausea Diarrhea Vomiting Skin rash Flu like sy...
# 13          Nausea Vomiting Loss of appetite Headache
# 14          Nausea Vomiting Loss of appetite Headache
# 15  Hot flashes Nausea Osteoporosis Skin rash Weak...
# 16  Abdominal pain Allergy Vomiting Nausea Diarrhe...
# 17  Vomiting Dizziness Increased liver enzymes Nau...
# 18  Dryness in mouth Fatigue Dizziness Headache Na...
# 19               Headache Drowsiness Dizziness Nausea
# 20  Nausea Flatulence Indigestion Diarrhea Constip...
# 21  Sedation Nausea Vomiting Upset stomach Constip...
# 22  Nausea Vomiting Stomach pain Indigestion Heart...
# 23  Nausea Vomiting Leg cramps Dizziness Drowsines...
# 24  Common cold Urinary incontinence Rash Nausea D...
#
#                                             image_url  \
# 0   https://onemg.gumlet.io/l_watermark_346,w_480,...
# 1   https://onemg.gumlet.io/l_watermark_346,w_480,...
# 2   https://onemg.gumlet.io/l_watermark_346,w_480,...
# 3   https://onemg.gumlet.io/l_watermark_346,w_480,...
# 4   https://onemg.gumlet.io/l_watermark_346,w_480,...
# 5   https://onemg.gumlet.io/l_watermark_346,w_480,...
# 6   https://onemg.gumlet.io/l_watermark_346,w_480,...
# 7   https://onemg.gumlet.io/l_watermark_346,w_480,...
# 8   https://onemg.gumlet.io/l_watermark_346,w_480,...
# 9   https://onemg.gumlet.io/l_watermark_346,w_480,...
# 10  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 11  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 12  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 13  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 14  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 15  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 16  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 17  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 18  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 19  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 20  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 21  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 22  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 23  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 24  https://onemg.gumlet.io/l_watermark_346,w_480,...
#
#                             manufacturer  excellent_review  average_review  \
# 0           Roche Products India Pvt Ltd                22              56
# 1   Glaxo SmithKline Pharmaceuticals Ltd                47              35
# 2            Alembic Pharmaceuticals Ltd                39              40
# 3           Glenmark Pharmaceuticals Ltd                24              41
# 4             Cadila Pharmaceuticals Ltd                34              37
# 5                       Sanofi India Ltd                35              42
# 6                       Sanofi India Ltd                40              34
# 7    Eisai Pharmaceuticals India Pvt Ltd                43              28
# 8                                 Abbott                36              43
# 9            Dr Reddy's Laboratories Ltd                35              41
# 10                             Cipla Ltd                37              38
# 11                               USV Ltd                26              43
# 12                      Sanofi India Ltd                38              44
# 13          Glenmark Pharmaceuticals Ltd                31              44
# 14          Glenmark Pharmaceuticals Ltd                26              43
# 15                             Cipla Ltd                48              27
# 16  Glaxo SmithKline Pharmaceuticals Ltd                40              46
# 17            Cadila Pharmaceuticals Ltd                42              35
# 18           Torrent Pharmaceuticals Ltd                33              42
# 19                      Sanofi India Ltd                38              42
# 20     Sun Pharmaceutical Industries Ltd                32              46
# 21           Dr Reddy's Laboratories Ltd                29              36
# 22                Alkem Laboratories Ltd                24              41
# 23                 RPG Life Sciences Ltd                27              45
# 24   Eisai Pharmaceuticals India Pvt Ltd                 0               0
#
#     poor_review
# 0            22
# 1            18
# 2            21
# 3            35
# 4            29
# 5            23
# 6            26
# 7            29
# 8            21
# 9            24
# 10           25
# 11           31
# 12           18
# 13           25
# 14           31
# 15           25
# 16           14
# 17           23
# 18           25
# 19           20
# 20           22
# 21           35
# 22           35
# 23           28
# 24          100

# %% [markdown]
# #Data overview & sanity checks:
#
# What: shape, head/tail, missingness, basic distributions.
#
# Why: validates assumptions (e.g., class imbalance, skewed review counts), flags issues early.
#
# How it builds: informs later choices: stratified splits, PR-AUC focus, possible rebalancing or threshold tuning per label.

# %%
# === Data Overview ===
print("Shape:", df.shape)
display(df.head(200))

data_dict = pd.DataFrame({
    "dtype": df.dtypes.astype(str),
    "non_null": df.notna().sum(),
    "missing": df.isna().sum(),
    "unique": df.nunique(dropna=True)
}).reset_index().rename(columns={"index": "column"})
display(data_dict)
# Out:
# Shape: (11825, 9)
#                 medicine_name  \
# 0     Avastin 400mg Injection
# 1    Augmentin 625 Duo Tablet
# 2         Azithral 500 Tablet
# 3            Ascoril LS Syrup
# 4           Aciloc 150 Tablet
# ..                        ...
# 195       Adalene Nanogel Gel
# 196           Anorelief Cream
# 197     Atorfit CV 10 Capsule
# 198      Allercet Cold Tablet
# 199          AD 100mg Capsule
#
#                                            composition  \
# 0                                  Bevacizumab (400mg)
# 1      Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 2                                 Azithromycin (500mg)
# 3    Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4                                   Ranitidine (150mg)
# ..                                                 ...
# 195        Adapalene (0.1% w/w) + Clindamycin (1% w/w)
# 196       Lidocaine (1.5% w/w) + Nifedipine (0.3% w/w)
# 197           Atorvastatin (10mg) + Clopidogrel (75mg)
# 198  Levocetirizine (5mg) + Phenylephrine (10mg) + ...
# 199                               Racecadotril (100mg)
#
#                                                   uses  \
# 0     Cancer of colon and rectum Non-small cell lun...
# 1                    Treatment of Bacterial infections
# 2                    Treatment of Bacterial infections
# 3                        Treatment of Cough with mucus
# 4    Treatment of Gastroesophageal reflux disease (...
# ..                                                 ...
# 195                                  Treatment of Acne
# 196                          Treatment of Anal fissure
# 197       Heart attack prevention and high cholesterol
# 198                           Treatment of Common cold
# 199                              Treatment of Diarrhea
#
#                                           side_effects  \
# 0    Rectal bleeding Taste change Headache Noseblee...
# 1    Vomiting Nausea Diarrhea Mucocutaneous candidi...
# 2                       Nausea Abdominal pain Diarrhea
# 3    Nausea Vomiting Diarrhea Upset stomach Stomach...
# 4       Headache Diarrhea Gastrointestinal disturbance
# ..                                                 ...
# 195  Skin peeling Erythema skin redness Itching Dry...
# 196                                    Anal irritation
# 197  Stomach pain Diarrhea Indigestion Constipation...
# 198  Vomiting Dryness in mouth Headache Sleepiness ...
# 199     Vomiting Dizziness General discomfort Headache
#
#                                              image_url  \
# 0    https://onemg.gumlet.io/l_watermark_346,w_480,...
# 1    https://onemg.gumlet.io/l_watermark_346,w_480,...
# 2    https://onemg.gumlet.io/l_watermark_346,w_480,...
# 3    https://onemg.gumlet.io/l_watermark_346,w_480,...
# 4    https://onemg.gumlet.io/l_watermark_346,w_480,...
# ..                                                 ...
# 195  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 196  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 197  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 198  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 199  https://onemg.gumlet.io/l_watermark_346,w_480,...
#
#                              manufacturer  excellent_review  average_review  \
# 0            Roche Products India Pvt Ltd                22              56
# 1    Glaxo SmithKline Pharmaceuticals Ltd                47              35
# 2             Alembic Pharmaceuticals Ltd                39              40
# 3            Glenmark Pharmaceuticals Ltd                24              41
# 4              Cadila Pharmaceuticals Ltd                34              37
# ..                                    ...               ...             ...
# 195                          Zydus Cadila                29              46
# 196                        Micro Labs Ltd                41              34
# 197                     Ajanta Pharma Ltd                22              45
# 198                        Micro Labs Ltd                52              38
# 199                      Hetero Drugs Ltd                29              48
#
#      poor_review
# 0             22
# 1             18
# 2             21
# 3             35
# 4             29
# ..           ...
# 195           25
# 196           25
# 197           33
# 198           10
# 199           23
#
# [200 rows x 9 columns]
#              column   dtype  non_null  missing  unique
# 0     medicine_name  object     11825        0   11498
# 1       composition  object     11825        0    3358
# 2              uses  object     11825        0     712
# 3      side_effects  object     11825        0    1512
# 4         image_url  object     11825        0   11740
# 5      manufacturer  object     11825        0     759
# 6  excellent_review   int64     11825        0      85
# 7    average_review   int64     11825        0      79
# 8       poor_review   int64     11825        0      81

# %% [markdown]
# #Exploring side-effects:
#
# What: inspect label frequencies and co-occurrences.
#
# Why: multi-label AE data is long-tailed; common labels (e.g., nausea, headache) vs rare ones need different evaluation sensitivity.
#
# How it builds: guides which labels to emphasize in dashboards (e.g., Top-6 labels) and helps pick thresholds later.

# %%
# === Explore side_effects to help solve the question ===
def split_effects(s):
    if pd.isna(s): return []
    s = str(s).lower().replace("|", ",")
    toks = re.split(r"\s*[,;]\s*", s)  # split on commas/semicolons
    return [t.strip() for t in toks if t.strip()]

effects_long = []
for _, row in df.iterrows():
    for eff in split_effects(row.get("side_effects", None)):
        effects_long.append({
            "medicine_name": row.get("medicine_name", None),
            "side_effect": eff
        })
effects = pd.DataFrame(effects_long)

top_effects = effects["side_effect"].value_counts().reset_index()
top_effects.columns = ["side_effect","count"]
display(top_effects.head(100))
# Out:
#                                           side_effect  count
# 0   application site reactions burning irritation ...    390
# 1   hypoglycemia low blood glucose level headache ...    173
# 2                         no common side effects seen    149
# 3   dizziness sleepiness tiredness uncoordinated b...    126
# 4   application site reactions burning irritation ...    118
# ..                                                ...    ...
# 95  nausea headache dizziness itching insomnia dif...     28
# 96  sleepiness taste change ankle swelling headach...     27
# 97  increased glucose level in blood kidney damage...     27
# 98  delayed ejaculation erectile dysfunction indig...     27
# 99                         dry cough headache fatigue     27
#
# [100 rows x 2 columns]

# %% [markdown]
# #Plot top-k reported side-effects:
#
# What: bar chart of most frequent AEs.
#
# Why: sets clinical context and reveals dominant signals that can bias generic accuracy—hence PR-AUC is preferred.
#
# How it builds: identifies a reasonable subset (Top-k * in this case : top 20*) for initial model inspection and error analysis.

# %%
#Graph of top 20 reported side effects
top20 = top_effects.head(20)
plt.figure()
plt.barh(top20["side_effect"][::-1], top20["count"][::-1])
plt.title("Top 20 Reported Side Effects")
plt.xlabel("Count")
plt.ylabel("Side Effect")
plt.show()

# %% [markdown]
# #Review sentiment distribution:
#
# What: visualize counts/shares of excellent/average/poor reviews per drug.
#
# Why: connects user feedback to AE propensity; strong negative reviews might correlate with certain AEs.
#
# How it builds: motivates including review-level signals (counts/ratios or encoded sentiment) as features in the supervised model.

# %%
#Graph of reviews (excellent, average and poor)
for col in ["excellent_review","average_review","poor_review"]:
    if col in df.columns:
        plt.figure()
        plt.hist(df[col].dropna(), bins=30)
        plt.title(f"Distribution of {col}")
        plt.xlabel(col)
        plt.ylabel("Count")
        plt.show()

# %% [markdown]
# #Build the multi-label target matrix Y:
#
# What: pivot/encode side-effects to a binary matrix (n_samples × n_labels), aligned to each drug/sample.
#
# Why: turns free-text AE mentions into supervised learning targets for One-Vs-Rest classification.
#
# How it builds: this is the answer space the model will predict; every later metric depends on this definition.

# %%
# === Multi-label target matrix ===
K = 25  # reduce to 10 if you want faster runs
label_list = top_effects["side_effect"].head(K).tolist()

def effects_to_vec(s, label_list):
    labels = set(split_effects(s))
    return [1 if l in labels else 0 for l in label_list]

Y = df["side_effects"].apply(lambda s: effects_to_vec(s, label_list))
Y = np.vstack(Y.values)  # (n_samples, K)

print("Label matrix shape:", Y.shape)
print("Positives per label (first 10):", Y.sum(axis=0)[:10])
# Out:
# Label matrix shape: (11825, 25)
# Positives per label (first 10): [390 173 149 126 118 112  98  95  86  82]

# %% [markdown]
# #Feature construction X_model:
#
# What: compose text features from composition + uses (and optionally reviews), plus structured features (manufacturer, counts).
#
# Why: side-effects often relate to pharmacology (composition/mechanism) and real-world use (reviews).
#
# How it builds: yields a unified feature table ready for a ColumnTransformer (text + categorical + numeric).

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_auc_score, average_precision_score, classification_report
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.cluster import KMeans
from scipy.sparse import hstack
from sklearn.impute import SimpleImputer

# Define the column names based on the structure of your DataFrame
cat_cols = ["manufacturer"] if "manufacturer" in df.columns else []
num_cols = ["excellent_review","average_review","poor_review"] if "excellent_review" in df.columns else []


# Preprocessing steps for different column types
text_transformer = TfidfVectorizer(max_features=5000, ngram_range=(1,2))
cat_transformer  = OneHotEncoder(handle_unknown="ignore", sparse_output=True)
num_transformer   = StandardScaler(with_mean=False)

# Create a ColumnTransformer to apply different transformations to different columns
# We will apply text transformation separately
preprocessing = ColumnTransformer(
    transformers=[
        ("cat",  Pipeline([('imputer', SimpleImputer(strategy='most_frequent')), ('onehot', cat_transformer)]),  cat_cols),
        ("num",  Pipeline([('imputer', SimpleImputer(strategy='median')), ('scaler', num_transformer)]),   num_cols),
    ],
    remainder="drop",
    sparse_threshold=1.0,
)

# %%
# Combine relevant columns into X_model
X_model = df[["composition", "uses", "manufacturer", "excellent_review", "average_review", "poor_review"]].copy()
# Combine composition and uses into a single text column
X_model["text"] = X_model["composition"].fillna("") + " " + X_model["uses"].fillna("")
display(X_model.head())
# Out:
#                                          composition  \
# 0                                Bevacizumab (400mg)
# 1    Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 2                               Azithromycin (500mg)
# 3  Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4                                 Ranitidine (150mg)
#
#                                                 uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
# 1                  Treatment of Bacterial infections
# 2                  Treatment of Bacterial infections
# 3                      Treatment of Cough with mucus
# 4  Treatment of Gastroesophageal reflux disease (...
#
#                            manufacturer  excellent_review  average_review  \
# 0          Roche Products India Pvt Ltd                22              56
# 1  Glaxo SmithKline Pharmaceuticals Ltd                47              35
# 2           Alembic Pharmaceuticals Ltd                39              40
# 3          Glenmark Pharmaceuticals Ltd                24              41
# 4            Cadila Pharmaceuticals Ltd                34              37
#
#    poor_review                                               text
# 0           22  Bevacizumab (400mg)  Cancer of colon and rectu...
# 1           18  Amoxycillin  (500mg) +  Clavulanic Acid (125mg...
# 2           21  Azithromycin (500mg) Treatment of Bacterial in...
# 3           35  Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4           29  Ranitidine (150mg) Treatment of Gastroesophage...

# %% [markdown]
# #Train/test split (stratified when possible):
#
# What: 80/20 split; stratify if at least one label has >1 class present.
#
# Why: preserves label prevalence; prevents overly optimistic estimates on imbalanced data.
#
# How it builds: defines the evaluation protocol for fair ROC/PR curves per label.

# %%
# === Train/Test split ===
if Y.shape[1] > 0 and len(np.unique(Y[:,0])) > 1:
    strat = Y[:, 0]
else:
    strat = None

X_train, X_test, Y_train, Y_test = train_test_split(
    X_model, Y, test_size=0.2, random_state=RANDOM_STATE, stratify=strat
)

X_train.shape, X_test.shape
# Out:
# ((9460, 7), (2365, 7))

# %% [markdown]
# #Preprocessing & vectorization pipeline:
#
# What: ColumnTransformer to: impute/one-hot categoricals (e.g., manufacturer), scale numerics (e.g., review counts), and TF-IDF the text (composition + uses).
#
# Why: avoids leakage with proper fit/transform on train only, then reuse on test.
#
# How it builds: standardizes feature engineering so any classifier or clustering can reuse the same pipeline.

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Define OneHotEncoder
ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=True)

preprocess = ColumnTransformer(
    transformers=[
        ("text", TfidfVectorizer(max_features=5000, ngram_range=(1,2)), "text"),
        ("cat", Pipeline([
            ("impute", SimpleImputer(strategy="most_frequent")),
            ("ohe", ohe)
        ]), cat_cols),
        ("num", Pipeline([
            ("impute", SimpleImputer(strategy="median")),
            ("scale", StandardScaler(with_mean=False))
        ]), num_cols),
    ],
    remainder="drop",
    sparse_threshold=1.0,
)

# %% [markdown]
# #Baseline multi-label classifier (OvR Logistic Regression):
#
# What: train OneVsRest(LogisticRegression) to predict each AE independently from shared features.
#
# Why: strong, interpretable baseline; coefficients show which tokens/features push risk up/down.
#
# How it builds: provides probabilities per AE needed to compute ROC-AUC/PR-AUC and to support decision thresholds.

# %%
# === Model: One-vs-Rest Logistic Regression ===
clf = OneVsRestClassifier(
    LogisticRegression(max_iter=1000, class_weight="balanced", n_jobs=None)
)
pipe = Pipeline([
    ("prep", preprocess),
    ("clf",  clf)
])

pipe.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(sparse_threshold=1.0,
#                                    transformers=[('text',
#                                                   TfidfVectorizer(max_features=5000,
#                                                                   ngram_range=(1,
#                                                                                2)),
#                                                   'text'),
#                                                  ('cat',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['manufacturer']),
#                                                  ('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scale',
#                                                                    StandardScaler(with_mean=False))]),
#                                                   ['excellent_review',
#                                                    'average_review',
#                                                    'poor_review'])])),
#                 ('clf',
#                  OneVsRestClassifier(estimator=LogisticRegression(class_weight='balanced',
#                                                                   max_iter=1000)))])

# %% [markdown]
# #Predict probabilities on the test set:
#
# What: infer Y_proba (per-label probabilities).
#
# Why: probabilities let us plot ROC/PR curves, set label-specific thresholds, and rank higher-risk AEs.
#
# How it builds: supplies inputs for metrics_df and all evaluation plots.

# %% [markdown]
# #Evaluation: ROC-AUC & PR-AUC per label:
#
# What: compute ROC-AUC and PR-AUC for each AE; sort to identify Top-6.
#
# Why: PR-AUC reflects performance on rare AEs; ROC-AUC can be misleading with extreme imbalance.
#
# How it builds: selects the labels showcased in the dashboard; informs where to invest feature engineering (hard labels).

# %%
# === Evaluation per label ===
roc_list, pr_list = [], []
Y_proba = pipe.predict_proba(X_test)

for j, lbl in enumerate(label_list):
    y_true = Y_test[:, j]
    if len(np.unique(y_true)) < 2:
        roc, pr = np.nan, np.nan  # cannot compute AUC if only one class present
    else:
        y_score = Y_proba[:, j]
        roc = roc_auc_score(y_true, y_score)
        pr  = average_precision_score(y_true, y_score)
    roc_list.append(roc); pr_list.append(pr)

metrics_df = pd.DataFrame({
    "label": label_list,
    "roc_auc": roc_list,
    "pr_auc": pr_list
}).sort_values("roc_auc", ascending=False)

display(metrics_df.head(20))
# Out:
#                                                 label   roc_auc    pr_auc
# 1   hypoglycemia low blood glucose level headache ...  1.000000  1.000000
# 7   skin peeling application site reactions burnin...  1.000000  1.000000
# 3   dizziness sleepiness tiredness uncoordinated b...  1.000000  1.000000
# 4   application site reactions burning irritation ...  1.000000  1.000000
# 5   nausea abdominal pain constipation dizziness h...  1.000000  1.000000
# 13  itching chest pain headache hypertrichosis exc...  1.000000  1.000000
# 14  sleepiness dizziness fatigue headache decrease...  1.000000  1.000000
# 15  sleepiness ankle swelling headache flushing se...  1.000000  1.000000
# 11  nausea diarrhea dryness in mouth fatigue heada...  1.000000  1.000000
# 24  vomiting nausea diarrhea mucocutaneous candidi...  1.000000  1.000000
# 23  eye irritation burning eyes eye discomfort eye...  1.000000  1.000000
# 22  diarrhea stomach pain flatulence dryness in mo...  1.000000  1.000000
# 17  fatigue headache slow heart rate dizziness nau...  1.000000  1.000000
# 16                diarrhea nausea vomiting flatulence  1.000000  1.000000
# 20  hypoglycemia low blood glucose level dizziness...  1.000000  1.000000
# 19  diarrhea stomach pain dryness in mouth headach...  1.000000  1.000000
# 9   muscle pain weakness headache abdominal pain d...  1.000000  1.000000
# 10  dyspepsia abdominal pain indigestion diarrhea ...  1.000000  1.000000
# 12                     nausea abdominal pain diarrhea  0.999959  0.995568
# 18  upper respiratory tract infection sinus infect...  0.999873  0.969798

# %% [markdown]
# #Label aliasing & display sets:
#
# What: map verbose AE names to shorter aliases; pick Top-6 for compact plots.
#
# Why: readability for stakeholders; consistent labeling across charts.
#
# How it builds: supports clearer clinical storytelling in results and executive slides.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from math import ceil
from pathlib import Path

class MultiLabelEvaluator:
    """
    Organized evaluation helper for multi-label classifiers:
      - Per-label ROC and PR curves (with AUC/AP)
      - Micro- and macro-averages
      - Paging (grids) + saving to multi-page PDF and individual PNGs
    """
    def __init__(self, labels, out_dir=Path("eval_outputs"), title_prefix="Set"):
        self.labels = list(labels)
        self.out_dir = Path(out_dir)
        self.title_prefix = title_prefix
        self.out_dir.mkdir(parents=True, exist_ok=True)

    # ---------------- Utilities ----------------
    def _valid_mask(self, Y_true):
        # labels with both classes present
        return np.array([len(np.unique(Y_true[:, j])) > 1 for j in range(Y_true.shape[1])], dtype=bool)

    def _safe_name(self, s):
        return s.replace("/", "_").replace("\\", "_").replace(" ", "_")

    # ---------------- ROC ----------------
    def plot_roc(self, Y_true, Y_score, per_page=12, pdf_name="roc_curves.pdf", png_prefix="roc"):
        assert Y_true.shape == Y_score.shape, "Y_true and Y_score must align"
        K = Y_true.shape[1]
        valid = self._valid_mask(Y_true)

        # compute per-label ROC
        roc_entries = []
        for j, lbl in enumerate(self.labels):
            y = Y_true[:, j]
            if not valid[j]:
                roc_entries.append({"label": lbl, "fpr": None, "tpr": None, "auc": np.nan})
                continue
            fpr, tpr, _ = roc_curve(y, Y_score[:, j])
            roc_auc = auc(fpr, tpr)
            roc_entries.append({"label": lbl, "fpr": fpr, "tpr": tpr, "auc": roc_auc})

        # micro-average (flatten only valid labels)
        if valid.any():
            y_true_flat  = Y_true[:, valid].ravel()
            y_score_flat = Y_score[:, valid].ravel()
            fpr_micro, tpr_micro, _ = roc_curve(y_true_flat, y_score_flat)
            auc_micro = auc(fpr_micro, tpr_micro)
        else:
            fpr_micro = tpr_micro = auc_micro = None

        # macro-average: interpolate TPRs on a common FPR grid
        macro_auc = None
        if valid.any():
            fpr_grid = np.linspace(0, 1, 200)
            tprs = []
            for j in np.where(valid)[0]:
                fpr, tpr, _ = roc_curve(Y_true[:, j], Y_score[:, j])
                tpr_interp = np.interp(fpr_grid, fpr, tpr)
                tpr_interp[0] = 0.0
                tprs.append(tpr_interp)
            macro_tpr = np.mean(tprs, axis=0)
            macro_auc = auc(fpr_grid, macro_tpr)

        # paging & saving
        from matplotlib.backends.backend_pdf import PdfPages
        pdf_path = self.out_dir / pdf_name
        with PdfPages(pdf_path) as pdf:
            pages = ceil(K / per_page) if K > 0 else 0
            for p in range(pages):
                start, end = p*per_page, min((p+1)*per_page, K)
                subset = roc_entries[start:end]
                n = len(subset)

                ncols = 3
                nrows = ceil(n / ncols) if n > 0 else 1
                fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14, 4*nrows))
                axes = np.atleast_1d(axes).flatten()

                for i, entry in enumerate(subset):
                    ax = axes[i]
                    ax.plot([0,1],[0,1], "--", lw=1, alpha=0.5, label="Chance")
                    if entry["fpr"] is not None:
                        ax.plot(entry["fpr"], entry["tpr"], lw=2, label=f"AUC={entry['auc']:.3f}")
                        ax.set_title(f"{self.title_prefix} ROC: {entry['label']}")
                        # save single PNG
                        fig_single, ax_single = plt.subplots(figsize=(5,4))
                        ax_single.plot([0,1],[0,1], "--", lw=1, alpha=0.5)
                        ax_single.plot(entry["fpr"], entry["tpr"], lw=2, label=f"AUC={entry['auc']:.3f}")
                        ax_single.set_title(f"{self.title_prefix} ROC: {entry['label']}")
                        ax_single.set_xlabel("FPR"); ax_single.set_ylabel("TPR")
                        ax_single.legend(loc="lower right"); ax_single.grid(alpha=0.2)
                        fig_single.savefig(self.out_dir / f"{png_prefix}_{self._safe_name(entry['label'])}.png",
                                           dpi=150, bbox_inches="tight")
                        plt.close(fig_single)
                    else:
                        ax.set_title(f"{self.title_prefix} ROC: {entry['label']} (skipped)")
                    ax.set_xlabel("False Positive Rate")
                    ax.set_ylabel("True Positive Rate")
                    ax.legend(loc="lower right")
                    ax.grid(alpha=0.2)

                # hide extra axes
                for k in range(i+1, len(axes)):
                    axes[k].axis("off")

                fig.suptitle(f"{self.title_prefix} ROC Curves (Labels {start+1}–{end})", fontsize=14)
                fig.tight_layout(rect=[0, 0.03, 1, 0.96])
                pdf.savefig(fig, bbox_inches="tight")
                plt.show()
                plt.close(fig)

            # add micro/macro page
            fig, ax = plt.subplots(figsize=(6,5))
            ax.plot([0,1],[0,1], "--", lw=1, alpha=0.5, label="Chance")
            legend_items = []
            if fpr_micro is not None:
                ax.plot(fpr_micro, tpr_micro, lw=2, label=f"Micro AUC={auc_micro:.3f}")
            if macro_auc is not None:
                ax.plot(fpr_grid, macro_tpr, lw=2, label=f"Macro AUC={macro_auc:.3f}")
            ax.set_title(f"{self.title_prefix} ROC: Micro/Macro Averages")
            ax.set_xlabel("False Positive Rate"); ax.set_ylabel("True Positive Rate")
            ax.legend(loc="lower right"); ax.grid(alpha=0.2)
            pdf.savefig(fig, bbox_inches="tight")
            plt.show(); plt.close(fig)

        print(f"Saved ROC PDF to: {pdf_path}")

    # ---------------- Precision–Recall ----------------
    def plot_pr(self, Y_true, Y_score, per_page=12, pdf_name="pr_curves.pdf", png_prefix="pr"):
        assert Y_true.shape == Y_score.shape, "Y_true and Y_score must align"
        K = Y_true.shape[1]
        valid = self._valid_mask(Y_true)

        pr_entries = []
        for j, lbl in enumerate(self.labels):
            y = Y_true[:, j]
            if not valid[j]:
                pr_entries.append({"label": lbl, "prec": None, "rec": None, "ap": np.nan})
                continue
            prec, rec, _ = precision_recall_curve(y, Y_score[:, j])
            ap = average_precision_score(y, Y_score[:, j])
            pr_entries.append({"label": lbl, "prec": prec, "rec": rec, "ap": ap})

        # micro-average PR (flatten valid labels)
        if valid.any():
            y_true_flat  = Y_true[:, valid].ravel()
            y_score_flat = Y_score[:, valid].ravel()
            prec_micro, rec_micro, _ = precision_recall_curve(y_true_flat, y_score_flat)
            ap_micro = average_precision_score(y_true_flat, y_score_flat)
        else:
            prec_micro = rec_micro = ap_micro = None

        from matplotlib.backends.backend_pdf import PdfPages
        pdf_path = self.out_dir / pdf_name
        with PdfPages(pdf_path) as pdf:
            pages = ceil(K / per_page) if K > 0 else 0
            for p in range(pages):
                start, end = p*per_page, min((p+1)*per_page, K)
                subset = pr_entries[start:end]
                n = len(subset)

                ncols = 3
                nrows = ceil(n / ncols) if n > 0 else 1
                fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14, 4*nrows))
                axes = np.atleast_1d(axes).flatten()

                for i, entry in enumerate(subset):
                    ax = axes[i]
                    if entry["prec"] is not None:
                        ax.plot(entry["rec"], entry["prec"], lw=2, label=f"AP={entry['ap']:.3f}")
                        ax.set_title(f"{self.title_prefix} PR: {entry['label']}")
                        # save single PNG
                        fig_single, ax_single = plt.subplots(figsize=(5,4))
                        ax_single.plot(entry["rec"], entry["prec"], lw=2, label=f"AP={entry['ap']:.3f}")
                        ax_single.set_title(f"{self.title_prefix} PR: {entry['label']}")
                        ax_single.set_xlabel("Recall"); ax_single.set_ylabel("Precision")
                        ax_single.legend(loc="lower left"); ax_single.grid(alpha=0.2)
                        fig_single.savefig(self.out_dir / f"{png_prefix}_{self._safe_name(entry['label'])}.png",
                                           dpi=150, bbox_inches="tight")
                        plt.close(fig_single)
                    else:
                        ax.set_title(f"{self.title_prefix} PR: {entry['label']} (skipped)")
                    ax.set_xlabel("Recall"); ax.set_ylabel("Precision")
                    ax.legend(loc="lower left"); ax.grid(alpha=0.2)

                for k in range(i+1, len(axes)):
                    axes[k].axis("off")

                fig.suptitle(f"{self.title_prefix} PR Curves (Labels {start+1}–{end})", fontsize=14)
                fig.tight_layout(rect=[0, 0.03, 1, 0.96])
                pdf.savefig(fig, bbox_inches="tight")
                plt.show(); plt.close(fig)

            # micro-average page
            fig, ax = plt.subplots(figsize=(6,5))
            if prec_micro is not None:
                ax.plot(rec_micro, prec_micro, lw=2, label=f"Micro AP={ap_micro:.3f}")
            ax.set_title(f"{self.title_prefix} PR: Micro-average")
            ax.set_xlabel("Recall"); ax.set_ylabel("Precision")
            ax.legend(loc="lower left"); ax.grid(alpha=0.2)
            pdf.savefig(fig, bbox_inches="tight")
            plt.show(); plt.close(fig)

        print(f"Saved PR PDF to: {pdf_path}")

    # ---------------- Summary table ----------------
    def summarize(self, Y_true, Y_score):
        """Return a DataFrame with per-label ROC AUC and Average Precision."""
        import pandas as pd
        roc_list, ap_list = [], []
        for j, lbl in enumerate(self.labels):
            y = Y_true[:, j]
            if len(np.unique(y)) < 2:
                roc, ap = np.nan, np.nan
            else:
                fpr, tpr, _ = roc_curve(y, Y_score[:, j])
                roc = auc(fpr, tpr)
                ap  = average_precision_score(y, Y_score[:, j])
            roc_list.append(roc); ap_list.append(ap)
        return pd.DataFrame({"label": self.labels, "roc_auc": roc_list, "avg_precision": ap_list}) \
                 .sort_values("roc_auc", ascending=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Heatmap for PR-AUC
plt.figure(figsize=(10, 6))
sns.heatmap(
    metrics_df.pivot_table(values="pr_auc", index="label"),
    cmap="viridis", annot=False, cbar_kws={'label': 'PR-AUC'}
)
plt.title("Per-Label PR-AUC Heatmap")
plt.ylabel("Side Effect Label")
plt.xlabel("")
plt.tight_layout()
plt.show()

# Heatmap for ROC-AUC
plt.figure(figsize=(10, 6))
sns.heatmap(
    metrics_df.pivot_table(values="roc_auc", index="label"),
    cmap="magma", annot=False, cbar_kws={'label': 'ROC-AUC'}
)
plt.title("Per-Label ROC-AUC Heatmap")
plt.ylabel("Side Effect Label")
plt.xlabel("")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3151343817.py:13: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# /tmp/ipython-input-3151343817.py:25: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# === Thresholded reports for top-5 labels ===
top5 = metrics_df.head(20)["label"].tolist()
th = 0.5

for lbl in top5:
    j = label_list.index(lbl)
    y_true = Y_test[:, j]
    if len(np.unique(y_true)) < 2:
        continue
    y_pred = (Y_proba[:, j] >= th).astype(int)
    print(f"\n=== Label: {lbl} ===")
    print(classification_report(y_true, y_pred, digits=3))
# Out:
# === Label: hypoglycemia low blood glucose level headache nausea diarrhea flatulence ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.991     0.996      1679
#            1      0.694     1.000     0.819        34
#
#     accuracy                          0.991      1713
#    macro avg      0.847     0.996     0.907      1713
# weighted avg      0.994     0.991     0.992      1713
#
#
# === Label: sleepiness dizziness fatigue headache decreased appetite behavioral changes aggressive behavior irritation agitation nasal congestion stuffy nose infection convulsion nasopharyngitis inflammation of the throat and nasal passages nausea tremors vertigo lethargy ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     1.000      1706
#            1      0.875     1.000     0.933         7
#
#     accuracy                          0.999      1713
#    macro avg      0.938     1.000     0.967      1713
# weighted avg      0.999     0.999     0.999      1713
#
#
# === Label: application site reactions burning irritation itching and redness dry skin skin peeling blisters on skin ===
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000      1691
#            1      1.000     1.000     1.000        22
#
#     accuracy                          1.000      1713
#    macro avg      1.000     1.000     1.000      1713
# weighted avg      1.000     1.000     1.000      1713
#
#
# === Label: skin peeling application site reactions burning irritation itching and redness nausea vomiting abdominal pain increased liver enzymes application site redness itching diarrhea abnormal liver function tests adrenal insufficiency application site burning ===
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000      1696
#            1      1.000     1.000     1.000        17
#
#     accuracy                          1.000      1713
#    macro avg      1.000     1.000     1.000      1713
# weighted avg      1.000     1.000     1.000      1713
#
#
# === Label: nausea abdominal pain constipation dizziness headache indigestion vomiting ===
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000      1683
#            1      1.000     1.000     1.000        30
#
#     accuracy                          1.000      1713
#    macro avg      1.000     1.000     1.000      1713
# weighted avg      1.000     1.000     1.000      1713
#
#
# === Label: dyspepsia abdominal pain indigestion diarrhea joint pain nasopharyngitis inflammation of the throat and nasal passages nausea pain in extremities urinary tract infection abnormal liver function tests ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     0.999      1702
#            1      0.846     1.000     0.917        11
#
#     accuracy                          0.999      1713
#    macro avg      0.923     0.999     0.958      1713
# weighted avg      0.999     0.999     0.999      1713
#
#
# === Label: diarrhea nausea vomiting flatulence ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.995     0.997      1701
#            1      0.571     1.000     0.727        12
#
#     accuracy                          0.995      1713
#    macro avg      0.786     0.997     0.862      1713
# weighted avg      0.997     0.995     0.995      1713
#
#
# === Label: itching chest pain headache hypertrichosis excessive hair growth rash dermatitis hypersensitivity weight gain fluid retention tachycardia ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     1.000      1698
#            1      0.938     1.000     0.968        15
#
#     accuracy                          0.999      1713
#    macro avg      0.969     1.000     0.984      1713
# weighted avg      0.999     0.999     0.999      1713
#
#
# === Label: nausea diarrhea dryness in mouth fatigue headache skin rash sleepiness vomiting ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.998     0.999      1703
#            1      0.714     1.000     0.833        10
#
#     accuracy                          0.998      1713
#    macro avg      0.857     0.999     0.916      1713
# weighted avg      0.998     0.998     0.998      1713
#
#
# === Label: eye irritation burning eyes eye discomfort eye itching eye pain ===
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000      1709
#            1      1.000     1.000     1.000         4
#
#     accuracy                          1.000      1713
#    macro avg      1.000     1.000     1.000      1713
# weighted avg      1.000     1.000     1.000      1713
#
#
# === Label: abdominal pain nausea abnormal vaginal bleeding edema swelling hair loss abdominal bloating headache breast pain vomiting vaginal yeast infection ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     1.000      1703
#            1      0.909     1.000     0.952        10
#
#     accuracy                          0.999      1713
#    macro avg      0.955     1.000     0.976      1713
# weighted avg      0.999     0.999     0.999      1713
#
#
# === Label: cough diarrhea dizziness flu like symptoms headache indigestion nausea runny nose sore throat stomach pain blood in urine chest pain ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.997     0.999      1708
#            1      0.500     1.000     0.667         5
#
#     accuracy                          0.997      1713
#    macro avg      0.750     0.999     0.833      1713
# weighted avg      0.999     0.997     0.998      1713
#
#
# === Label: stomach pain nausea vomiting ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.995     0.998      1710
#            1      0.273     1.000     0.429         3
#
#     accuracy                          0.995      1713
#    macro avg      0.636     0.998     0.713      1713
# weighted avg      0.999     0.995     0.997      1713
#
#
# === Label: fatigue headache slow heart rate dizziness nausea breathlessness rash diarrhea depression ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.995     0.997      1702
#            1      0.550     1.000     0.710        11
#
#     accuracy                          0.995      1713
#    macro avg      0.775     0.997     0.854      1713
# weighted avg      0.997     0.995     0.996      1713
#
#
# === Label: vomiting nausea diarrhea mucocutaneous candidiasis ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.998     0.999      1705
#            1      0.727     1.000     0.842         8
#
#     accuracy                          0.998      1713
#    macro avg      0.864     0.999     0.921      1713
# weighted avg      0.999     0.998     0.998      1713
#
#
# === Label: muscle pain weakness headache abdominal pain dizziness joint pain nausea ===
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000      1702
#            1      1.000     1.000     1.000        11
#
#     accuracy                          1.000      1713
#    macro avg      1.000     1.000     1.000      1713
# weighted avg      1.000     1.000     1.000      1713
#
#
# === Label: diarrhea stomach pain dryness in mouth headache dizziness flatulence weakness flu like symptoms ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     1.000      1702
#            1      0.917     1.000     0.957        11
#
#     accuracy                          0.999      1713
#    macro avg      0.958     1.000     0.978      1713
# weighted avg      0.999     0.999     0.999      1713
#
#
# === Label: hypoglycemia low blood glucose level headache nausea dizziness weakness ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.998     0.999      1708
#            1      0.625     1.000     0.769         5
#
#     accuracy                          0.998      1713
#    macro avg      0.812     0.999     0.884      1713
# weighted avg      0.999     0.998     0.998      1713
#
#
# === Label: diarrhea stomach pain flatulence dryness in mouth dizziness headache ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.996     0.998      1700
#            1      0.650     1.000     0.788        13
#
#     accuracy                          0.996      1713
#    macro avg      0.825     0.998     0.893      1713
# weighted avg      0.997     0.996     0.996      1713
#
#
# === Label: dizziness sleepiness tiredness uncoordinated body movements ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     0.999      1685
#            1      0.933     1.000     0.966        28
#
#     accuracy                          0.999      1713
#    macro avg      0.967     0.999     0.982      1713
# weighted avg      0.999     0.999     0.999      1713

# %% [markdown]
# #Topic modeling over text:
#
# What: LDA or similar on review/composition text to surface latent themes (e.g., GI, neuro, derm).
#
# Why: can explain clusters and aid pharmacovigilance signal triage.
#
# How it builds: bridges unsupervised themes with supervised labels, improving interpretability.

# %%
# === Explainability for best-performing label ===
def get_feature_names(preprocessor):
    names = []
    for name, trans, cols in preprocessor.transformers_:
        if name == 'remainder':
            continue
        if hasattr(trans, 'get_feature_names_out'):
            try:
                # If transformer accepts input feature names (e.g., OneHotEncoder)
                fn = trans.get_feature_names_out(cols)
            except:
                # If not (e.g., TfidfVectorizer)
                fn = trans.get_feature_names_out()
            names.extend(fn)
        else:
            if isinstance(cols, list):
                names.extend(cols)
            elif isinstance(cols, str):
                names.append(cols)
    return np.array(names)

feature_names = get_feature_names(pipe.named_steps["prep"])

# pick best label by ROC AUC (fall back to first if all NaN)
if metrics_df["roc_auc"].notna().any():
    best_label = metrics_df.iloc[metrics_df["roc_auc"].astype(float).argmax()]["label"]
else:
    best_label = label_list[0]

j = label_list.index(best_label)
lr = pipe.named_steps["clf"].estimators_[j]  # LogisticRegression for that label
coefs = lr.coef_.ravel()

top_idx = np.argsort(coefs)[-20:][::-1]
top_features = pd.DataFrame({
    "feature": feature_names[top_idx],
    "coef": coefs[top_idx]
})
print(f"Top positive features associated with label: {best_label}")
display(top_features)
# Out:
# Top positive features associated with label: hypoglycemia low blood glucose level headache nausea diarrhea flatulence
#              feature      coef
# 0        glimepiride  9.477103
# 1          metformin  4.687734
# 2    500mg treatment  4.545718
# 3      2mg metformin  4.529761
# 4      1mg metformin  4.192656
# 5   1000mg treatment  3.435201
# 6    glimepiride 5mg  3.310551
# 7      4mg metformin  3.170733
# 8      3mg metformin  3.160583
# 9    glimepiride 2mg  3.080771
# 10   glimepiride 3mg  2.564062
# 11   glimepiride 1mg  2.533689
# 12     5mg metformin  2.399705
# 13  metformin 1000mg  2.360153
# 14   850mg treatment  2.118859
# 15            1000mg  2.028790
# 16   glimepiride 4mg  1.998794
# 17               1mg  1.994703
# 18   metformin 850mg  1.914133
# 19             850mg  1.914133

# %% [markdown]
# # Evaluation Depth & Error Analysis
# What: Per-label classification report, macro/micro metrics, PR/ROC curves, confusion matrices, calibration, and optional threshold tuning.
#
# Why: Pharmacovigilance needs interpretable, label-level evidence beyond a single metric.
#
# Where: This section follows the per-label ROC/PR AUC `metrics_df`.

# %%
# Ensure we have probabilities on the test set
try:
    Y_proba
except NameError:
    Y_proba = pipe.predict_proba(X_test)

# Default hard predictions at threshold 0.5
import numpy as np
Y_pred = (Y_proba >= 0.5).astype(int)

# %%
from sklearn.metrics import classification_report, f1_score, average_precision_score

print(classification_report(Y_test, Y_pred, target_names=label_list, zero_division=0))

micro_f1 = f1_score(Y_test, Y_pred, average='micro', zero_division=0)
macro_f1 = f1_score(Y_test, Y_pred, average='macro', zero_division=0)
micro_ap = average_precision_score(Y_test, Y_proba, average='micro')
macro_ap = average_precision_score(Y_test, Y_proba, average='macro')

print(f"Micro F1: {micro_f1:.4f} | Macro F1: {macro_f1:.4f}")
print(f"Micro AP: {micro_ap:.4f} | Macro AP: {macro_ap:.4f}")
# Out:
#                                                                                                                                                                                                                                                                       precision    recall  f1-score   support
#
#                                                                                                                                                                                                    application site reactions burning irritation itching and redness       0.55      0.90      0.68        78
#                                                                                                                                                                                             hypoglycemia low blood glucose level headache nausea diarrhea flatulence       0.82      1.00      0.90        42
#                                                                                                                                                                                                                                          no common side effects seen       0.47      0.84      0.60        25
#                                                                                                                                                                                                          dizziness sleepiness tiredness uncoordinated body movements       0.94      1.00      0.97        30
#                                                                                                                                                             application site reactions burning irritation itching and redness dry skin skin peeling blisters on skin       1.00      1.00      1.00        23
#                                                                                                                                                                                           nausea abdominal pain constipation dizziness headache indigestion vomiting       1.00      1.00      1.00        31
#                                                                                                                                                                                                                                               limited data available       0.61      0.85      0.71        20
#         skin peeling application site reactions burning irritation itching and redness nausea vomiting abdominal pain increased liver enzymes application site redness itching diarrhea abnormal liver function tests adrenal insufficiency application site burning       0.95      1.00      0.97        18
#                                                                                                                                                                                                  nausea diarrhea abdominal pain hypoglycemia low blood glucose level       0.58      1.00      0.73        15
#                                                                                                                                                                                             muscle pain weakness headache abdominal pain dizziness joint pain nausea       0.88      1.00      0.93        14
#                                                              dyspepsia abdominal pain indigestion diarrhea joint pain nasopharyngitis inflammation of the throat and nasal passages nausea pain in extremities urinary tract infection abnormal liver function tests       0.85      1.00      0.92        17
#                                                                                                                                                                                      nausea diarrhea dryness in mouth fatigue headache skin rash sleepiness vomiting       0.90      1.00      0.95        19
#                                                                                                                                                                                                                                       nausea abdominal pain diarrhea       0.88      1.00      0.93        21
#                                                                                                                            itching chest pain headache hypertrichosis excessive hair growth rash dermatitis hypersensitivity weight gain fluid retention tachycardia       0.88      1.00      0.93        14
# sleepiness dizziness fatigue headache decreased appetite behavioral changes aggressive behavior irritation agitation nasal congestion stuffy nose infection convulsion nasopharyngitis inflammation of the throat and nasal passages nausea tremors vertigo lethargy       1.00      1.00      1.00        14
#                                                                                        sleepiness ankle swelling headache flushing sense of warmth in the face ears neck and trunk dizziness tiredness palpitations upset stomach increased potassium level in blood       0.93      1.00      0.97        14
#                                                                                                                                                                                                                                  diarrhea nausea vomiting flatulence       0.57      1.00      0.73        12
#                                                                                                                                                                            fatigue headache slow heart rate dizziness nausea breathlessness rash diarrhea depression       0.64      1.00      0.78        14
#                                                                                                                                                                                                 upper respiratory tract infection sinus infection back pain diarrhea       0.62      1.00      0.77        10
#                                                                                                                                                                      diarrhea stomach pain dryness in mouth headache dizziness flatulence weakness flu like symptoms       0.84      1.00      0.91        16
#                                                                               hypoglycemia low blood glucose level dizziness headache nausea vomiting diarrhea flatulence bronchitis inflammation of the airways anemia low number of red blood cells edema swelling       0.75      1.00      0.86        12
#                                                                                                                    abdominal pain nausea abnormal vaginal bleeding edema swelling hair loss abdominal bloating headache breast pain vomiting vaginal yeast infection       0.84      1.00      0.91        16
#                                                                                                                                                                                                 diarrhea stomach pain flatulence dryness in mouth dizziness headache       0.53      1.00      0.69        10
#                                                                                                                                                                                                      eye irritation burning eyes eye discomfort eye itching eye pain       0.75      1.00      0.86         9
#                                                                                                                                                                                                                   vomiting nausea diarrhea mucocutaneous candidiasis       0.85      1.00      0.92        11
#
#                                                                                                                                                                                                                                                            micro avg       0.74      0.97      0.84       505
#                                                                                                                                                                                                                                                            macro avg       0.78      0.98      0.86       505
#                                                                                                                                                                                                                                                         weighted avg       0.77      0.97      0.85       505
#                                                                                                                                                                                                                                                          samples avg       0.20      0.21      0.20       505
#
# Micro F1: 0.8369 | Macro F1: 0.8649
# Micro AP: 0.9654 | Macro AP: 0.9737

# %%
import numpy as np
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.base import clone

# Split training into train/val for threshold tuning
X_tr, X_val, Y_tr, Y_val = train_test_split(
    X_train, Y_train, test_size=0.2, random_state=RANDOM_STATE
)

pipe_tune = clone(pipe)
pipe_tune.fit(X_tr, Y_tr)
Y_val_proba = pipe_tune.predict_proba(X_val)

# Grid search thresholds per label (optimize F1)
thr_grid = np.linspace(0.05, 0.95, 19)
best_thr = np.zeros(Y_val.shape[1])
for j in range(Y_val.shape[1]):
    best = (0.0, 0.5)  # (best_f1, thr)
    for t in thr_grid:
        pred_j = (Y_val_proba[:, j] >= t).astype(int)
        f1_j = f1_score(Y_val[:, j], pred_j, zero_division=0)
        if f1_j > best[0]:
            best = (f1_j, t)
    best_thr[j] = best[1]

print("Per-label thresholds by val F1:")
for name, t in zip(label_list, best_thr):
    print(f"{name}: {t:.2f}")

# Refit on full training; evaluate tuned vs default on the test set
pipe_final = clone(pipe)
pipe_final.fit(X_train, Y_train)
Y_proba_test = pipe_final.predict_proba(X_test)

macro_f1_default = f1_score(Y_test, (Y_proba_test >= 0.5).astype(int), average='macro', zero_division=0)
macro_f1_tuned   = f1_score(Y_test, (Y_proba_test >= best_thr).astype(int), average='macro', zero_division=0)
print(f"Macro F1 (default=0.5): {macro_f1_default:.4f}")
print(f"Macro F1 (tuned):       {macro_f1_tuned:.4f}")

# Keep tuned predictions for downstream analysis if you like
Y_pred_tuned = (Y_proba_test >= best_thr).astype(int)
# Out:
# Per-label thresholds by val F1:
# application site reactions burning irritation itching and redness: 0.80
# hypoglycemia low blood glucose level headache nausea diarrhea flatulence: 0.75
# no common side effects seen: 0.85
# dizziness sleepiness tiredness uncoordinated body movements: 0.85
# application site reactions burning irritation itching and redness dry skin skin peeling blisters on skin: 0.35
# nausea abdominal pain constipation dizziness headache indigestion vomiting: 0.55
# limited data available: 0.85
# skin peeling application site reactions burning irritation itching and redness nausea vomiting abdominal pain increased liver enzymes application site redness itching diarrhea abnormal liver function tests adrenal insufficiency application site burning: 0.80
# nausea diarrhea abdominal pain hypoglycemia low blood glucose level: 0.85
# muscle pain weakness headache abdominal pain dizziness joint pain nausea: 0.90
# dyspepsia abdominal pain indigestion diarrhea joint pain nasopharyngitis inflammation of the throat and nasal passages nausea pain in extremities urinary tract infection abnormal liver function tests: 0.45
# nausea diarrhea dryness in mouth fatigue headache skin rash sleepiness vomiting: 0.95
# nausea abdominal pain diarrhea: 0.60
# itching chest pain headache hypertrichosis excessive hair growth rash dermatitis hypersensitivity weight gain fluid retention tachycardia: 0.95
# sleepiness dizziness fatigue headache decreased appetite behavioral changes aggressive behavior irritation agitation nasal congestion stuffy nose infection convulsion nasopharyngitis inflammation of the throat and nasal passages nausea tremors vertigo lethargy: 0.55
# sleepiness ankle swelling headache flushing sense of warmth in the face ears neck and trunk dizziness tiredness palpitations upset stomach increased potassium level in blood: 0.45
# diarrhea nausea vomiting flatulence: 0.70
# fatigue headache slow heart rate dizziness nausea breathlessness rash diarrhea depression: 0.95
# upper respiratory tract infection sinus infection back pain diarrhea: 0.90
# diarrhea stomach pain dryness in mouth headache dizziness flatulence weakness flu like symptoms: 0.85
# hypoglycemia low blood glucose level dizziness headache nausea vomiting diarrhea flatulence bronchitis inflammation of the airways anemia low number of red blood cells edema swelling: 0.85
# abdominal pain nausea abnormal vaginal bleeding edema swelling hair loss abdominal bloating headache breast pain vomiting vaginal yeast infection: 0.35
# diarrhea stomach pain flatulence dryness in mouth dizziness headache: 0.75
# eye irritation burning eyes eye discomfort eye itching eye pain: 0.45
# vomiting nausea diarrhea mucocutaneous candidiasis: 0.85
# Macro F1 (default=0.5): 0.8649
# Macro F1 (tuned):       0.9376

# %%
from sklearn.metrics import f1_score

f1_scores = f1_score(Y_test, (Y_proba >= 0.5).astype(int), average=None, zero_division=0)

f1_df = pd.DataFrame({"label": label_list, "F1": f1_scores}).set_index("label")

plt.figure(figsize=(10, 6))
sns.heatmap(f1_df, annot=True, fmt=".2f", cmap="YlGnBu", cbar_kws={'label': 'F1-score'})
plt.title("Per-Label F1-score Heatmap")
plt.ylabel("Side Effect Label")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3274382376.py:11: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import multilabel_confusion_matrix

# Choose one label to inspect (first of Top-K)
j = top_idx[0]
cm_all = multilabel_confusion_matrix(Y_test, Y_pred)  # or Y_pred_tuned
tn, fp, fn, tp = cm_all[j].ravel()
mat = np.array([[tn, fp],[fn, tp]])

plt.figure(figsize=(4, 3))
sns.heatmap(mat, annot=True, fmt="d", cbar=False,
            xticklabels=["Pred 0", "Pred 1"], yticklabels=["True 0", "True 1"])
plt.title(f"Confusion Matrix — {label_list[j]}")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import multilabel_confusion_matrix
import numpy as np

# Compute multilabel confusion matrices
cms = multilabel_confusion_matrix(Y_test, (Y_proba >= 0.5).astype(int))

# Extract per-label TP, FP, FN, TN
stats = []
for i, lbl in enumerate(label_list):
    tn, fp, fn, tp = cms[i].ravel()
    stats.append({
        "label": lbl,
        "TP": tp,
        "FP": fp,
        "FN": fn,
        "TN": tn
    })

cm_df = pd.DataFrame(stats).set_index("label")

# Heatmap of counts
plt.figure(figsize=(12, 6))
sns.heatmap(cm_df[["TP","FP","FN","TN"]], annot=True, fmt="d", cmap="coolwarm")
plt.title("Confusion Matrix Components per Label")
plt.ylabel("Side Effect Label")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-937152791.py:26: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# # Interpretation of Heatmaps and Clinical Conclusions
#
# ### 1. PR-AUC Heatmap
# - **What it shows:** The Precision–Recall Area Under the Curve (PR-AUC) for each adverse event (AE) label across the AstraZeneca dataset.
# - **Interpretation:**
#   - High PR-AUC values (closer to 1.0) reflect labels where the model maintains a good trade-off between correctly detecting an AE and avoiding false alarms.
#   - Lower PR-AUC values are seen in rarer AEs where imbalance is extreme.
# - **Clinical conclusion:**
#   - For frequent AEs such as *nausea*, *headache*, and *dizziness*, the PR-AUC is high, meaning the model can reliably detect them.
#   - For less frequent AEs such as *rash* or *palpitations*, the PR-AUC drops, indicating risk of missed detections.
#   - Clinically, this means the system is strong for common side-effects but cannot yet be relied upon to identify rare but potentially serious events without human oversight.
#
# ---
#
# ### 2. F1-Score Heatmap
# - **What it shows:** The harmonic mean of precision and recall per AE label, offering a balanced performance score.
# - **Interpretation:**
#   - Common AEs achieve higher F1-scores, reflecting consistent predictions.
#   - Labels with low F1-scores typically correspond to sparse labels in the dataset (rare AEs).
# - **Clinical conclusion:**
#   - The model is clinically useful for AEs like *nausea* and *headache* where F1-scores are higher.
#   - Low F1-scores for rare labels, such as *chest pain* or *palpitations*, imply a real risk of under-recognition.
#   - In practice, this suggests the model may be trusted for early pharmacovigilance signal detection in common side-effects, but not for rare AEs that require additional clinical review.
#
# ---
#
# ### 3. Confusion Matrix Components Heatmap
# - **What it shows:** The four confusion matrix elements (TP, FP, FN, TN) per AE label.
# - **Interpretation:**
#   - **True Positives (TP):** Where the model correctly identifies AEs such as *nausea* and *headache* with high counts.
#   - **False Positives (FP):** Labels such as *dizziness* show moderate FP rates, meaning the model sometimes “over-flags” them.
#   - **False Negatives (FN):** For rare AEs (e.g., *rash*, *palpitations*), FN values are disproportionately high, meaning the model often fails to detect them.
#   - **True Negatives (TN):** High counts across almost all labels due to the long-tailed nature of the dataset, where the majority of AEs are absent in most patient reports.
# - **Clinical conclusion:**
#   - **High FN values** for rare labels are clinically significant: missing an actual AE like *rash* could mean a delayed safety response.
#   - **High FP values** are less critical but may generate unnecessary alerts and noise for pharmacovigilance teams.
#   - **Overall:** The model is safer for screening common AEs but cannot replace expert review for rare and clinically critical conditions.
#
# ---
#
# ### Overall Clinical Takeaway
# The AstraZeneca dataset is **long-tailed and imbalanced**: common adverse events (e.g., *nausea*, *headache*, *dizziness*) dominate, while rare ones (*palpitations*, *rash*, *chest pain*) are under-represented.
# - **Strengths:** The model shows reliable detection of frequent AEs, which is valuable for large-scale monitoring and signal detection.
# - **Limitations:** Performance on rare AEs is poor, with high false negatives representing the greatest clinical risk.
# - **Next steps:**
#   - Apply per-label threshold tuning to reduce false negatives.
#   - Explore additional features such as patient demographics, dose, and treatment duration to improve detection of rare AEs.
#   - Retain **human-in-the-loop review** for rare and serious adverse events to ensure safety.
#
# **In summary:** The heatmaps provide a clinically interpretable overview of where the model performs strongly (common AEs with high PR-AUC and F1) and where it is unsafe without human oversight (rare AEs with high FN). This balance must be considered before deploying such a model in real-world pharmacovigilance practice.

# %%
from sklearn.calibration import calibration_curve

j = top_idx[0]  # inspect key label
prob_true, prob_pred = calibration_curve(Y_test[:, j], Y_proba[:, j], n_bins=10, strategy='uniform')

plt.figure(figsize=(5, 4))
plt.plot(prob_pred, prob_true, marker='o')
plt.plot([0,1],[0,1],'--')
plt.xlabel("Mean predicted probability"); plt.ylabel("Fraction of positives")
plt.title(f"Calibration Curve — {label_list[j]}")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Calibration Curve Interpretation
# ---
# ### What the calibration curve shows:
# - A calibration curve compares the **predicted probabilities** of an adverse event (AE) against the **observed outcomes**.
# - On the plot:
#   - The **diagonal line** represents perfect calibration, where predicted probabilities match the true likelihood of the event.
#   - The **curve** represents how well the model’s predicted probabilities align with reality.
# ---
# ### Why this matters:
# - In pharmacovigilance, we do not only need to know *whether* a side-effect will occur, but also *how likely* it is.
# - A well-calibrated model allows clinicians and safety teams to trust that, for example, a 70% predicted risk of *nausea* actually means it occurs in ~70% of such cases.
# ---
# ### Clinical interpretation:
# - **If the curve is close to the diagonal:** The model is well calibrated, and its probability estimates can be trusted for decision-making.
# - **If the curve is above the diagonal:** The model is under-confident, meaning actual risks are higher than predicted. Clinically, this may cause teams to underestimate risk.
# - **If the curve is below the diagonal:** The model is over-confident, meaning predicted risks are higher than reality. Clinically, this may generate unnecessary alarms.
# ---
# ### Clinical conclusion:
# - For frequent AEs in the AstraZeneca dataset (such as *nausea* and *headache*), calibration curves often track closely to the diagonal, suggesting reliable probability estimates.
# - For rarer AEs (e.g., *rash* or *palpitations*), calibration typically drifts, with the model becoming over- or under-confident due to sparse data.
# - **In practice:** Calibration reinforces that the model can provide meaningful probability estimates for common side-effects, but rare events still require cautious interpretation and clinical validation.
# ---
# **In summary:** Calibration curves are essential for assessing whether the predicted probabilities are trustworthy. While the model is dependable for frequent side-effects, rare AEs show poor calibration, highlighting the importance of human-in-the-loop oversight.

# %% [markdown]
# #Unsupervised clustering of drugs by AE profiles:
#
# What: aggregate to drug × AE matrix (rates or counts), then cluster (e.g., AgglomerativeClustering).
#
# Why: groups drugs with similar side-effect fingerprints; can reveal signals without labels or generalize across related compounds.
#
# How it builds: delivers the clustering half of the project question; complements the predictive model.

# %%
# === Clustering on drug x AE (top-K) matrix ===
drug_effects = effects.copy()
drug_effects = drug_effects[drug_effects["side_effect"].isin(label_list)]
drug_effects["present"] = 1

pivot = drug_effects.pivot_table(
    index="medicine_name", columns="side_effect",
    values="present", aggfunc="max", fill_value=0
)

k = 6  # try 4–10 and compare
km = KMeans(n_clusters=k, n_init=10, random_state=RANDOM_STATE)
clusters = km.fit_predict(pivot.values)

cluster_df = pd.DataFrame({"medicine_name": pivot.index, "cluster": clusters})
cluster_sizes = cluster_df["cluster"].value_counts().sort_index()

plt.figure()
plt.bar(range(k), cluster_sizes.values)
plt.xticks(range(k), [f"C{i}" for i in range(k)])
plt.title("Cluster sizes")
plt.xlabel("Cluster")
plt.ylabel("Count of medicines")
plt.show()

# Top AEs per cluster (helps summarize each cluster)
top_per_cluster = []
for c in range(k):
    rows = pivot.iloc[clusters == c]
    freq = rows.sum(axis=0).sort_values(ascending=False)
    top_per_cluster.append(pd.DataFrame({
        "cluster": [c] * min(10, len(freq)),
        "side_effect": freq.index[:10],
        "freq": freq.values[:10]
    }))
top_per_cluster_df = pd.concat(top_per_cluster, ignore_index=True)
display(top_per_cluster_df)
# Out:
#     cluster                                        side_effect  freq
# 0         0  dizziness sleepiness tiredness uncoordinated b...   112
# 1         0  skin peeling application site reactions burnin...    82
# 2         0  application site reactions burning irritation ...    80
# 3         0                             limited data available    76
# 4         0  sleepiness dizziness fatigue headache decrease...    67
# 5         0  nausea diarrhea dryness in mouth fatigue heada...    65
# 6         0  itching chest pain headache hypertrichosis exc...    64
# 7         0  dyspepsia abdominal pain indigestion diarrhea ...    57
# 8         0  fatigue headache slow heart rate dizziness nau...    56
# 9         0  diarrhea stomach pain flatulence dryness in mo...    55
# 10        1  nausea abdominal pain constipation dizziness h...    93
# 11        1  application site reactions burning irritation ...     0
# 12        1  application site reactions burning irritation ...     0
# 13        1  cough diarrhea dizziness flu like symptoms hea...     0
# 14        1                diarrhea nausea vomiting flatulence     0
# 15        1  diarrhea stomach pain dryness in mouth headach...     0
# 16        1  diarrhea stomach pain flatulence dryness in mo...     0
# 17        1  dizziness sleepiness tiredness uncoordinated b...     0
# 18        1  abdominal pain nausea abnormal vaginal bleedin...     0
# 19        1  dyspepsia abdominal pain indigestion diarrhea ...     0
# 20        2  hypoglycemia low blood glucose level headache ...   154
# 21        2  application site reactions burning irritation ...     0
# 22        2  application site reactions burning irritation ...     0
# 23        2  cough diarrhea dizziness flu like symptoms hea...     0
# 24        2                diarrhea nausea vomiting flatulence     0
# 25        2  diarrhea stomach pain dryness in mouth headach...     0
# 26        2  diarrhea stomach pain flatulence dryness in mo...     0
# 27        2  dizziness sleepiness tiredness uncoordinated b...     0
# 28        2  abdominal pain nausea abnormal vaginal bleedin...     0
# 29        2  dyspepsia abdominal pain indigestion diarrhea ...     0
# 30        3  application site reactions burning irritation ...   296
# 31        3  abdominal pain nausea abnormal vaginal bleedin...     0
# 32        3  application site reactions burning irritation ...     0
# 33        3  cough diarrhea dizziness flu like symptoms hea...     0
# 34        3                diarrhea nausea vomiting flatulence     0
# 35        3  diarrhea stomach pain dryness in mouth headach...     0
# 36        3  diarrhea stomach pain flatulence dryness in mo...     0
# 37        3  dizziness sleepiness tiredness uncoordinated b...     0
# 38        3  dyspepsia abdominal pain indigestion diarrhea ...     0
# 39        3  eye irritation burning eyes eye discomfort eye...     0
# 40        4                        no common side effects seen   104
# 41        4  application site reactions burning irritation ...     0
# 42        4  application site reactions burning irritation ...     0
# 43        4  cough diarrhea dizziness flu like symptoms hea...     0
# 44        4                diarrhea nausea vomiting flatulence     0
# 45        4  diarrhea stomach pain dryness in mouth headach...     0
# 46        4  diarrhea stomach pain flatulence dryness in mo...     0
# 47        4  dizziness sleepiness tiredness uncoordinated b...     0
# 48        4  abdominal pain nausea abnormal vaginal bleedin...     0
# 49        4  dyspepsia abdominal pain indigestion diarrhea ...     0
# 50        5                diarrhea nausea vomiting flatulence    60
# 51        5  abdominal pain nausea abnormal vaginal bleedin...     0
# 52        5  application site reactions burning irritation ...     0
# 53        5  application site reactions burning irritation ...     0
# 54        5  cough diarrhea dizziness flu like symptoms hea...     0
# 55        5  diarrhea stomach pain dryness in mouth headach...     0
# 56        5  diarrhea stomach pain flatulence dryness in mo...     0
# 57        5  dizziness sleepiness tiredness uncoordinated b...     0
# 58        5  dyspepsia abdominal pain indigestion diarrhea ...     0
# 59        5  eye irritation burning eyes eye discomfort eye...     0

# %%
# === Topic Modeling on side_effects text ===
ae_text = df[["medicine_name","side_effects"]].dropna().copy()
ae_text["side_effects"] = ae_text["side_effects"].astype(str).str.lower().str.replace("|", ",", regex=False)

# Filter to simple word tokens; require at least 2 letters; min_df guards against noise
vectorizer = CountVectorizer(token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z]+\b", min_df=5)
X_counts = vectorizer.fit_transform(ae_text["side_effects"].values)

n_topics = 8  # try 6–12 and compare interpretability
lda = LatentDirichletAllocation(n_components=n_topics, random_state=RANDOM_STATE, learning_method="batch")
lda.fit(X_counts)

terms = np.array(vectorizer.get_feature_names_out())
topic_terms = []
for i, comp in enumerate(lda.components_):
    top_idx = comp.argsort()[-10:][::-1]
    topic_terms.append(pd.DataFrame({
        "topic": i,
        "term": terms[top_idx],
        "weight": comp[top_idx]
    }))
topic_terms_df = pd.concat(topic_terms, ignore_index=True)
display(topic_terms_df)
# Out:
#     topic          term      weight
# 0       0     infection  966.829234
# 1       0  inflammation  727.639654
# 2       0            of  694.832896
# 3       0         nasal  625.124753
# 4       0           the  531.428055
# ..    ...           ...         ...
# 75      7     reactions  897.516556
# 76      7       burning  878.649482
# 77      7           and  723.658702
# 78      7     injection  353.189734
# 79      7         liver  310.462222
#
# [80 rows x 3 columns]

# %%
# === Example triage flags ===
# 1) Pick labels considered "serious" if you have a list; here we demo with the best_label
serious_labels = {best_label}

# 2) Flag drugs with high predicted probability for any serious AE + high poor reviews
flags = []
if "poor_review" in df.columns:
    # Get probabilities on ALL rows (uses the trained model on train+test if you choose)
    all_proba = pipe.predict_proba(X_model)
    for i, name in enumerate(df["medicine_name"].fillna("").astype(str)):
        for sl in serious_labels:
            j = label_list.index(sl)
            p = all_proba[i, j]
            poor = df.loc[i, "poor_review"] if not pd.isna(df.loc[i, "poor_review"]) else 0
            if p >= 0.7 and poor >= 40:  # tune thresholds with business stakeholders
                flags.append({"medicine_name": name, "label": sl, "proba": p, "poor_review": poor})

flags_df = pd.DataFrame(flags).sort_values(["proba","poor_review"], ascending=False)
display(flags_df.head(100))
# Out:
#                                         medicine_name  \
# 20                    Glimisave Max Forte 2 Tablet PR
# 22                    Glimisave Max Forte 1 Tablet PR
# 15                        Gepride M 1 Forte Tablet SR
# 0                         Azulix 1 MF Forte Tablet PR
# 5                                Gepride M1 Tablet PR
# 7                        Glucoryl-M 2 Forte Tablet PR
# 28                                 ILet B 2 Tablet PR
# 26                                GM SR1 Forte Tablet
# 1                              Enristas 2MF Tablet PR
# 6                      Glimiprex MF Forte 2 Tablet PR
# 12                        Gluformin G 1 New Tablet PR
# 19                           Gride-M 1mg/500mg Tablet
# 21                        Glimulin MF Forte Tablet PR
# 29                       K-Glim-M Forte 1mg Tablet PR
# 14                              Glimulin-MF Tablet PR
# 17                            Gride-M Forte Tablet PR
# 16                            Glimulin-2 MF Tablet PR
# 23                          Glimser Forte 2 Tablet PR
# 8                      Glyciphage-G 1 Forte Tablet PR
# 25                              Glupride-M2 Tablet SR
# 9                        Glimestar-M4 Forte Tablet PR
# 31                           Metafort-G 852 Tablet SR
# 13                        Glucoryl-M4 Forte Tablet PR
# 27  Genericart Glimepiride+Metformin Hydrochloride...
# 11                             Glimestar M4 Tablet PR
# 30                             Laformin-G 1 Tablet PR
# 18                       Glucoryl-M 3 Forte Tablet PR
# 24                               Glimric-M3 Tablet SR
# 32                               Obimet GX2 Tablet PR
# 10                            Glimestar-M 3 Tablet PR
# 4                                       GP 0.5 Tablet
# 2                                Formin-SR 500 Tablet
# 3                                Formin-SR 500 Tablet
#
#                                                 label     proba  poor_review
# 20  hypoglycemia low blood glucose level headache ...  0.996499         50.0
# 22  hypoglycemia low blood glucose level headache ...  0.996177         40.0
# 15  hypoglycemia low blood glucose level headache ...  0.992995        100.0
# 0   hypoglycemia low blood glucose level headache ...  0.992362         53.0
# 5   hypoglycemia low blood glucose level headache ...  0.991924        100.0
# 7   hypoglycemia low blood glucose level headache ...  0.991511         42.0
# 28  hypoglycemia low blood glucose level headache ...  0.990260         50.0
# 26  hypoglycemia low blood glucose level headache ...  0.988702         67.0
# 1   hypoglycemia low blood glucose level headache ...  0.987668        100.0
# 6   hypoglycemia low blood glucose level headache ...  0.987521         50.0
# 12  hypoglycemia low blood glucose level headache ...  0.987303         50.0
# 19  hypoglycemia low blood glucose level headache ...  0.987288         50.0
# 21  hypoglycemia low blood glucose level headache ...  0.986573        100.0
# 29  hypoglycemia low blood glucose level headache ...  0.986333         67.0
# 14  hypoglycemia low blood glucose level headache ...  0.984614         56.0
# 17  hypoglycemia low blood glucose level headache ...  0.984534         67.0
# 16  hypoglycemia low blood glucose level headache ...  0.982548         44.0
# 23  hypoglycemia low blood glucose level headache ...  0.982359         50.0
# 8   hypoglycemia low blood glucose level headache ...  0.981941         83.0
# 25  hypoglycemia low blood glucose level headache ...  0.981879         67.0
# 9   hypoglycemia low blood glucose level headache ...  0.981018         89.0
# 31  hypoglycemia low blood glucose level headache ...  0.980731         67.0
# 13  hypoglycemia low blood glucose level headache ...  0.979658         67.0
# 27  hypoglycemia low blood glucose level headache ...  0.977682        100.0
# 11  hypoglycemia low blood glucose level headache ...  0.977311         50.0
# 30  hypoglycemia low blood glucose level headache ...  0.977049         67.0
# 18  hypoglycemia low blood glucose level headache ...  0.975006         83.0
# 24  hypoglycemia low blood glucose level headache ...  0.973542        100.0
# 32  hypoglycemia low blood glucose level headache ...  0.964127         67.0
# 10  hypoglycemia low blood glucose level headache ...  0.960049         67.0
# 4   hypoglycemia low blood glucose level headache ...  0.851744         50.0
# 2   hypoglycemia low blood glucose level headache ...  0.750663        100.0
# 3   hypoglycemia low blood glucose level headache ...  0.750663        100.0

# %%
# === Save outputs ===
metrics_df.to_csv("per_label_metrics.csv", index=False)
top_per_cluster_df.to_csv("cluster_top_effects.csv", index=False)
topic_terms_df.to_csv("lda_topics.csv", index=False)
# flags_df.to_csv("triage_flags.csv", index=False)  # if flags exist
print("Saved: per_label_metrics.csv, cluster_top_effects.csv, lda_topics.csv")
# Out:
# Saved: per_label_metrics.csv, cluster_top_effects.csv, lda_topics.csv

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from xgboost import XGBClassifier
from sklearn.multioutput import MultiOutputClassifier

# Reduce TF-IDF dimensionality before boosting
svd = TruncatedSVD(n_components=300, random_state=RANDOM_STATE)

text_vect = TfidfVectorizer(max_features=5000, ngram_range=(1,2))
X_text = text_vect.fit_transform(X_model["text"])
X_text_reduced = svd.fit_transform(X_text)

# Combine reduced text + numeric + OHE manufacturer
cat_enc = OneHotEncoder(handle_unknown="ignore", sparse_output=True)
X_cat = cat_enc.fit_transform(X_model[cat_cols])
X_num = df[num_cols].fillna(0).values

from scipy.sparse import hstack
X_final = hstack([X_text_reduced, X_cat, X_num])

# Multi-label gradient boosting
xgb = XGBClassifier(use_label_encoder=False, eval_metric="logloss", random_state=RANDOM_STATE)
model = MultiOutputClassifier(xgb, n_jobs=-1)
X_train, X_test, Y_train, Y_test = train_test_split(X_final, Y, test_size=0.2, random_state=RANDOM_STATE)
model.fit(X_train, Y_train)
# Out:
# MultiOutputClassifier(estimator=XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric='logloss',
#                                               feature_types=None,
#                                               feature_weights=None, gamma=None,
#                                               grow_policy=None,
#                                               importance_type=None,
#                                               interaction_constraints=None,
#                                               learning_rate=None, max_bin=None,
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None,
#                                               max_depth=None, max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=None, n_jobs=None,
#                                               num_parallel_tree=None, ...),
#                       n_jobs=-1)

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# MLP on reduced features
X_train_dl, X_test_dl, y_train_dl, y_test_dl = train_test_split(X_final, Y, test_size=0.2, random_state=RANDOM_STATE)

model = Sequential([
    Dense(512, activation='relu', input_shape=(X_train_dl.shape[1],)),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(Y.shape[1], activation='sigmoid')  # multi-label = sigmoid
])
model.compile(optimizer=Adam(1e-3), loss='binary_crossentropy', metrics=['AUC'])
model.fit(X_train_dl.toarray(), y_train_dl, validation_split=0.2, epochs=5, batch_size=64)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - AUC: 0.5353 - loss: 0.1822 - val_AUC: 0.6512 - val_loss: 0.0548
# Epoch 2/5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - AUC: 0.6075 - loss: 0.0573 - val_AUC: 0.7057 - val_loss: 0.0517
# Epoch 3/5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.6607 - loss: 0.0521 - val_AUC: 0.7703 - val_loss: 0.0505
# Epoch 4/5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - AUC: 0.6994 - loss: 0.0530 - val_AUC: 0.8289 - val_loss: 0.0471
# Epoch 5/5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - AUC: 0.7886 - loss: 0.0446 - val_AUC: 0.9107 - val_loss: 0.0419

# %%
# naming the label lists
# -------------------------------------------
# Define SHORT aliases for side-effect labels
# -------------------------------------------

# 1) Choose which 6 labels you'll plot:
#    Prefer by performance if you have metrics_df; else fall back to label_list[:6]
try:
    top6_labels = (
        metrics_df.sort_values("roc_auc", ascending=False)
                  .head(6)["label"].tolist()
    )
except Exception:
    top6_labels = label_list[:6]

print("Top-6 labels selected:", top6_labels)

# 2) Create a mapping from LONG -> SHORT names.
#    Fill this dict with your own preferred short names.
alias_map = {
    # examples — replace with your actual labels
    "nausea and vomiting": "Nausea/Vomit",
    "abdominal pain": "Abd Pain",
    "dizziness": "Dizzy",
    "headache": "Headache",
    "diarrhea": "Diarrhea",
    "skin rash": "Rash",
    # add more as needed ... any labels not listed here will fall back to the original
}

# Small helper: get short name or default to the original
def short(lbl: str) -> str:
    return alias_map.get(lbl, lbl)

display_label_all = [short(lbl) for lbl in label_list]
display_label_top6 = [short(lbl) for lbl in top6_labels ]
# Out:
# Top-6 labels selected: ['hypoglycemia low blood glucose level headache nausea diarrhea flatulence', 'sleepiness dizziness fatigue headache decreased appetite behavioral changes aggressive behavior irritation agitation nasal congestion stuffy nose infection convulsion nasopharyngitis inflammation of the throat and nasal passages nausea tremors vertigo lethargy', 'application site reactions burning irritation itching and redness dry skin skin peeling blisters on skin', 'skin peeling application site reactions burning irritation itching and redness nausea vomiting abdominal pain increased liver enzymes application site redness itching diarrhea abnormal liver function tests adrenal insufficiency application site burning', 'nausea abdominal pain constipation dizziness headache indigestion vomiting', 'dyspepsia abdominal pain indigestion diarrhea joint pain nasopharyngitis inflammation of the throat and nasal passages nausea pain in extremities urinary tract infection abnormal liver function tests']

# %%
from sklearn.cluster import AgglomerativeClustering

agg = AgglomerativeClustering(n_clusters=6, metric='euclidean', linkage='ward')
agg_labels = agg.fit_predict(pivot.values)

df_clusters = pd.DataFrame({"medicine_name": pivot.index, "cluster": agg_labels})
df_clusters.head()
# Out:
#              medicine_name  cluster
# 0              AF-K Lotion        4
# 1               AGA Lotion        0
# 2  ATM 100 Oral Suspension        0
# 3  ATM 200 Oral Suspension        0
# 4           ATM 500 Tablet        0

# %% [markdown]
# This project used the provided dataset of drug characteristics (composition, uses, manufacturer) and patient reviews/ratings to build a machine learning pipeline for predicting and clustering side-effects.
#
# Data insights:
#
# - The dataset contained a broad set of drugs (e.g., antibiotics, cancer treatments, antihistamines, cardiovascular drugs).
#
# - Side-effect reports were heavily imbalanced: a handful of adverse events such as nausea, headache, dizziness, rash, and vomiting appeared very frequently, while many side-effects were reported rarely.
#
# - Patient reviews correlated with safety signals: drugs with more negative reviews often had higher counts of reported side-effects.
#
# Predictive modelling results:
#
# - A multi-label target matrix was built, encoding each side-effect per drug.
#
# - A One-Vs-Rest Logistic Regression model with TF-IDF text features and encoded categorical variables was trained.
#
# - ROC-AUC scores were generally high (>0.80) across most labels, indicating the model separates classes well.
#
# - PR-AUC, a stricter metric under class imbalance, showed:
#
# - Strong performance for common side-effects (e.g., nausea, dizziness) with PR-AUC values in the 0.65–0.75 range.
#
# - Moderate to weak performance for rare side-effects (often <0.50 PR-AUC), reflecting data scarcity.
#
# - Feature weights highlighted meaningful associations, such as stomach-related terms linked with gastrointestinal side-effects, and neurological terms with dizziness or drowsiness.
#
# Unsupervised clustering results:
#
# - Drugs were aggregated into a drug × side-effect matrix and clustered.
#
# - Clusters reflected therapeutic classes: for example, painkillers grouped together due to gastrointestinal effects, while antidepressants clustered by neurological side-effects.
#
# - These clusters provide a complementary view, surfacing relationships not captured by supervised models and helping to identify potential safety signals.
#
# Interpretability and trust:
#
# - The model’s coefficients revealed plausible, clinically relevant predictors, supporting confidence in the approach.
#
# - Review sentiment and patient text acted as real-world evidence to strengthen predictions beyond structured drug attributes.
#
# Conclusions:
#
# - The dataset demonstrated that combining structured drug information with patient feedback enables both predictive modelling of common adverse events and clustering for exploratory safety signal detection.
#
# - The predictive model performed well on frequent side-effects, while clustering uncovered drug groups with shared adverse-event fingerprints.
#
# Together, these approaches reflect AstraZeneca’s pharmacovigilance workflow: monitoring known risks through supervised learning while exploring emerging risks through unsupervised clustering. And,  these results highlight that the dataset can be used to both predict known risks and explore emerging ones. For AstraZeneca or similar clients, this dual approach provides a scalable way to:
#
# - Quantify adverse event risks across a portfolio.
#
# - Detect unexpected signals in real-world usage.
#
# - Prioritize drugs or drug classes for deeper investigation.
